# %% [markdown]
# # **Population Of Pakistan**

# %% [markdown]
# ### **Description**
# Pakistan Population Dataset provides comprehensive demographic information about the population of Pakistan. This dataset includes a wide range of population statistics, such as:
#
# `Age Distribution:` Details about the population spread across various age groups, allowing for analysis of the age structure in different regions.
#
# `Gender Distribution:` Insights into the gender composition within the population.
#
# `Geographical Breakdown:` Data categorized by provinces and districts, offering a granular view of the population distribution across urban and rural areas.
#
# `Urban and Rural Population:` Information on the division of population between urban and rural areas, which is critical for urban planning and resource allocation.
#
# `Population Growth Trends:` Historical data that can be used to analyze trends in population growth over time.
#
# `Years of data`: 1998, 2017

# %% [markdown]
# ### **Data Source:**
# This dataset is collected for analysis from this website: [kaggle.com](https://www.kaggle.com/datasets/iqramahmood004/pakistan-population-dataset)

# %% [markdown]
# ## **Purpose of Analysis:**
#
# *To be filled at the end*

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
population_data = pd.read_csv(r'C:\Users\riyan\OneDrive\Desktop\Population of pakistan\data\sub-division_population_of_pakistan.csv')
population_data.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# Data composition 
population_data.shape
# Out:
# (528, 21)

# %%
population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
population_data.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
sns.boxplot(x='PROVINCE',y='ALL SEXES (RURAL)',data=population_data)
# Out:
# <Axes: xlabel='PROVINCE', ylabel='ALL SEXES (RURAL)'>

# %%
print('Population of Pakistan',(population_data['ALL SEXES (RURAL)'].sum() + population_data['ALL SEXES (URBAN)'].sum()))
# Out:
# Population of Pakistan 204410733

# %%
population_data.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
print('Increase in rural population: ', (population_data['ALL SEXES (RURAL)'].sum() - population_data['POPULATION 1998 (RURAL)'].sum()))
# Out:
# Increase in rural population:  41632809

# %%
population_data['ALL SEXES (RURAL)'].sum()
# Out:
# 130034790

# %%
population_data['POPULATION 1998 (RURAL)'].sum()
# Out:
# 88401981

# %%
increased_rural_population = population_data['ALL SEXES (RURAL)'].sum() - population_data['POPULATION 1998 (RURAL)'].sum()
increased_rural_population
# Out:
# 41632809

# %%
(increased_rural_population/population_data['POPULATION 1998 (RURAL)'].sum())*100
# Out:
# 47.094882409931515

# %%
population_data['PERCENT INCREASED (RURAL)'] = (population_data['ALL SEXES (RURAL)'] - population_data['POPULATION 1998 (RURAL)']) / population_data['POPULATION 1998 (RURAL)']*100

# %%
population_data.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
population_data.melt()
# Out:
#                         variable      value
# 0                       PROVINCE     PUNJAB
# 1                       PROVINCE     PUNJAB
# 2                       PROVINCE     PUNJAB
# 3                       PROVINCE     PUNJAB
# 4                       PROVINCE     PUNJAB
# ...                          ...        ...
# 11611  PERCENT INCREASED (RURAL)  36.241899
# 11612  PERCENT INCREASED (RURAL)  73.296899
# 11613  PERCENT INCREASED (RURAL)  19.751777
# 11614  PERCENT INCREASED (RURAL)  38.087542
# 11615  PERCENT INCREASED (RURAL)  68.726039
#
# [11616 rows x 2 columns]
